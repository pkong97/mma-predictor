# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("fight-database.csv")
df.head(10)
# Out:
#            event_id                              event_name             f1_id  \
# 0  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  6d1bffff14897645
# 1  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  3974fa35c917af1d
# 2  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  c21f26bbde777573
# 3  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  2e585c701f72fe55
# 4  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  7c7332319c14094c
# 5  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  98215d037be5bcb7
# 6  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  e51fcd9cd84c0b93
# 7  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  a0f0004aadf10b71
# 8  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  bf0e700106d00e55
# 9  aa3153a9941b4d44  UFC Fight Night: Magny vs. Ponzinibbio  a12a8314adc1c1c9
#
#                 f1_name             f2_id              f2_name  \
# 0  Santiago Ponzinibbio  84b3e7d38f2d2ec5           Neil Magny
# 1         Ricardo Lamas  92a9aa9c93192871        Darren Elkins
# 2         Johnny Walker  749f572d1d3161fb  Khalil Rountree Jr.
# 3          Ian Heinisch  dbc17725b887860a       Cezar Ferreira
# 4           Marlon Vera  d05412b513b19621       Guido Cannetti
# 5      Cynthia Calvillo  5c126c6aac3ef364      Poliana Botelho
# 6       Michel Prazeres  e17ac6410c8377f4     Bartosz Fabinski
# 7     Alexandre Pantoja  7c3c48cf54a2848e          Ulka Sasaki
# 8         Austin Arnett  2c2caf2f2bab9df5    Humberto Bandenay
# 9    Laureano Staropoli  c487223b0289bda9        Hector Aldana
#
#           winner_id        event_id.1  method
# 0  6d1bffff14897645  aa3153a9941b4d44  KO/TKO
# 1  3974fa35c917af1d  aa3153a9941b4d44  KO/TKO
# 2  c21f26bbde777573  aa3153a9941b4d44  KO/TKO
# 3  2e585c701f72fe55  aa3153a9941b4d44   U-DEC
# 4  7c7332319c14094c  aa3153a9941b4d44     SUB
# 5  98215d037be5bcb7  aa3153a9941b4d44     SUB
# 6  e51fcd9cd84c0b93  aa3153a9941b4d44     SUB
# 7  a0f0004aadf10b71  aa3153a9941b4d44     SUB
# 8  bf0e700106d00e55  aa3153a9941b4d44   U-DEC
# 9  a12a8314adc1c1c9  aa3153a9941b4d44   U-DEC

# %%
df['method'].value_counts()
# Out:
# KO/TKO        1645
# U-DEC         1622
# SUB           1031
# S-DEC          462
# M-DEC           55
# Overturned      34
# DQ              14
# CNC             13
# Other            2
# Name: method, dtype: int64

# %%
movs = ["KO/TKO", "U-DEC", "M-DEC", "S-DEC", "SUB", "DQ"]
for i in range(0,len(df)):
    if any(x in df.loc[i, 'method'] for x in movs ) == False:
        df = df.drop(index = i)
        df.reset_index

# %%
df['method'].value_counts()
# Out:
# KO/TKO    1645
# U-DEC     1622
# SUB       1031
# S-DEC      462
# M-DEC       55
# DQ          14
# Name: method, dtype: int64
